# %%
import pandas as pd

# %%
from FileName import classname

# %%
dataset = pd.read_csv('Placement.csv')

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
Qual,Quan = classname.univariate(dataset)

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
#My reference 
object = dataset.select_dtypes(include = 'object')

# %%
object.head()
# Out:
#   gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0      M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1      M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2      M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3      M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4      M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
#
#        status
# 0      Placed
# 1      Placed
# 2      Placed
# 3  Not Placed
# 4      Placed

# %%
dataset.gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
dataset.workex.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Count quantitative (numeric) and qualitative (categorical) data
quan_count = sum(dataset.dtypes != 'object')
qual_count = sum(dataset.dtypes == 'object')
# Get the total number of columns
total_columns = dataset.shape[1]

# %%
quan_count
# Out:
# 7

# %%
qual_count
# Out:
# 8

# %%
total_columns
# Out:
# 15

# %% [markdown]
# # Finded all Central tendency with IQR(interquartile Range), min and max ans lesser and greater IQR!

# %%
descriptive = classname.central_tendency_IQR(dataset, Quan)

# %%
descriptive
# Out:
#              sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean         108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median       108.0       67.0       65.0       66.0       71.0       62.0
# Mode             1       62.0       63.0       65.0       60.0       56.7
# Q1:25%        54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%       108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%       161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%        215       89.4       97.7       91.0       98.0      77.89
# IQR          107.0       15.1       12.1       11.0       23.5       8.31
# Lesser IQR  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater IQR  322.0      98.35      91.15       88.5     118.75      78.72
# min              1      40.89       37.0       50.0       50.0      51.21
# max            215       89.4       97.7       91.0       98.0      77.89
#
# ...

# %% [markdown]
# # Check outliers

# %%
lesser,greater = classname.check_outliers(dataset, descriptive, Quan)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %% [markdown]
# # Replace outliers

# %%
classname.replace_outliers(dataset, descriptive, lesser, greater)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Recheck outliers

# %%
descriptive = classname.central_tendency_IQR(dataset, Quan)

# %%
recheck_lesser, recheck_greater = classname.recheck_outliers_after_replace(dataset, descriptive, Quan)

# %%
recheck_lesser
# Out:
# []

# %%
recheck_greater
# Out:
# []

# %% [markdown]
# # Frequency, Relative, cumulative Freq

# %%
classname.freqTable(dataset, "ssc_p")
# Out:
#      Unique_values  Freq  Relative_freq  Cumulative_freq
# 0            62.00    11       5.116279         5.116279
# 1            63.00    10       4.651163         9.767442
# 2            67.00     9       4.186047        13.953488
# 3            52.00     9       4.186047        18.139535
# 4            73.00     9       4.186047        22.325581
# ..             ...   ...            ...              ...
# 98           69.70     1       0.465116        98.139535
# 99           80.92     1       0.465116        98.604651
# 100          83.00     1       0.465116        99.069767
# 101          86.50     1       0.465116        99.534884
# 102          80.60     1       0.465116       100.000000
#
# [103 rows x 4 columns]

# %%
classname.freqTable(dataset, "salary")
# Out:
#     Unique_values  Freq  Relative_freq  Cumulative_freq
# 0        300000.0    22      14.864865        14.864865
# 1        250000.0    18      12.162162        27.027027
# 2        390000.0    15      10.135135        37.162162
# 3        240000.0    15      10.135135        47.297297
# 4        260000.0     7       4.729730        52.027027
# 5        200000.0     6       4.054054        56.081081
# 6        265000.0     6       4.054054        60.135135
# 7        360000.0     6       4.054054        64.189189
# 8        275000.0     5       3.378378        67.567568
# 9        220000.0     5       3.378378        70.945946
# 10       270000.0     4       2.702703        73.648649
# 11       210000.0     4       2.702703        76.351351
# 12       350000.0     3       2.027027        78.378378
# 13       216000.0     3       2.027027        80.405405
# 14       204000.0     2       1.351351        81.756757
# 15       236000.0     2       1.351351        83.108108
# ...

# %% [markdown]
# # Histogram, Skewness, Kurtosis
